# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
data=r"C:\Users\Asus\OneDrive\Desktop\Machine learning\Medical_report.csv"
df=pd.read_csv(data)

# %%
df.head()
# Out:
#    Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0        30           80.0        120              240          10
# 1        30           85.0        120              250          10
# 2        45           90.0        130              260           8
# 3        45           95.0        130              270           8
# 4        45          100.0        140              280           0
#
#    Hours_Sleep
# 0            7
# 1            7
# 2            7
# 3            7
# 4            7

# %%
df.tail()
# Out:
#     Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 10        80          134.0        140              400           8
# 11        35            NaN        140              200           8
# 12       100          145.0        150              300           5
# 13        45          100.0        120              250           8
# 14        65          100.0        130              300           9
#
#     Hours_Sleep
# 10            6
# 11            7
# 12            6
# 13            9
# 14            8

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         15 non-null     int64
#  1   Average_Pulse    14 non-null     float64
#  2   Max_Pulse        15 non-null     int64
#  3   Calorie_Burnage  15 non-null     int64
#  4   Hours_Work       15 non-null     int64
#  5   Hours_Sleep      15 non-null     int64
# dtypes: float64(1), int64(5)
# memory usage: 852.0 bytes

# %%
df.shape
# Out:
# (15, 6)

# %%
df.isnull().sum()
# Out:
# Duration           0
# Average_Pulse      1
# Max_Pulse          0
# Calorie_Burnage    0
# Hours_Work         0
# Hours_Sleep        0
# dtype: int64

# %%
df['Average_Pulse'].fillna(df['Average_Pulse'].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# Duration           0
# Average_Pulse      0
# Max_Pulse          0
# Calorie_Burnage    0
# Hours_Work         0
# Hours_Sleep        0
# dtype: int64

# %%
scaler=StandardScaler()
standardized_data= scaler.fit_transform(df)
standardized_df=pd.DataFrame(standardized_data, columns=df.columns)

# %%
df.head()
# Out:
#    Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0        30           80.0        120              240          10
# 1        30           85.0        120              250          10
# 2        45           90.0        130              260           8
# 3        45           95.0        130              270           8
# 4        45          100.0        140              280           0
#
#    Hours_Sleep
# 0            7
# 1            7
# 2            7
# 3            7
# 4            7

# %%
x= df[['Calorie_Burnage','Duration','Hours_Work','Hours_Sleep']]
y = df['Average_Pulse']

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.25,random_state=42)

# %%
xtrain
# Out:
#     Calorie_Burnage  Duration  Hours_Work  Hours_Sleep
# 5               290        60           7            8
# 8               320        75           0            8
# 2               260        45           8            7
# 1               250        30          10            7
# 14              300        65           9            8
# 4               280        45           0            7
# 7               310        60           8            8
# 10              400        80           8            6
# 12              300       100           5            6
# 3               270        45           8            7
# 6               300        60           7            8

# %%
xtest
# Out:
#     Calorie_Burnage  Duration  Hours_Work  Hours_Sleep
# 9               330        75           8            8
# 11              200        35           8            7
# 0               240        30          10            7
# 13              250        45           8            9

# %%
pdict=LinearRegression()

# %%
pdict.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
y_predict=pdict.predict(xtest)

# %%
y_predict=pdict.predict([[450,100,15,5]])

# %%
pdict.score(x,y)
# Out:
# 0.7735309630863431

# %%
x.shape
# Out:
# (15, 4)

# %%
y_predict.shape
# Out:
# (1,)

# %%
data = pd.DataFrame(y_predict, columns=['Average_Pulse',])
print(data)
# Out:
#    Average_Pulse
# 0     154.080424

# %%
r2_score(y,pdict.predict(xtest))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 r2_score(y,pdict.predict(xtest))
#
# File D:\New folder\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
# ...
